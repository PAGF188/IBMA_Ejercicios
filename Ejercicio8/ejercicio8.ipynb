# %% [markdown]
# # IPBMA_8: CT Sinogram
#
# **Authors**:
# - Pablo García Fernández (pablo.garcia.fernandez2@rai.usc.es)
# - Javier Goya Pérez (javier.goya@rai.usc.es)
# - Sindy Rocío Mojica Gómez (sindyrocio.mojica@rai.usc.es)

# %%
# Configuration
import numpy as np
import matplotlib.pyplot as plt
# %run ./funciones.py
# %run ./funciones_phantoms.py

# %% [markdown]
# READING SINOGRAM

# %%
pSinograma= np.load('sinogram.npy')

# %%
plt.imshow(pSinograma, cmap="gray")
plt.show()

# %%
# RECONSTRUCTOR
# 8 Projections, just to check

rImage = reconstructor(pSinograma, 8)

# %%
plt.imshow(rImage, cmap="gray")
plt.show()

# %%
# RECONSTRUCTOR

nProjections= 360
rImage= reconstructor(pSinograma, nProjections)

# %%
plt.imshow(rImage, cmap="gray")
plt.show()

# %%
nLine= int(rImage.shape[0]/2)
plotLineH(rImage, nLine)

# %%
# TRANSFORM TO HOUNSFIELD UNITS
eE= 40
hImage= setHounsfield(rImage, eE)
# Out:
# Coef agua: 0.2683

# %%
plt.imshow(hImage, cmap="gray")
plt.show()

# %%
nLine= int(hImage.shape[0]/2)
plotLineH(hImage, nLine)

# %%
# W/L DISPLAY

vImage= displayWL(hImage, 50, 1500, 255)
plt.imshow(vImage, cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3785/2006850582.py in <module>
#       2
#       3 vImage= displayWL(hImage, 50, 1500, 255)
# ----> 4 plt.imshow(vImage, cmap="gray")
#       5 plt.show()
#
# ~/anaconda3/envs/fipa/lib/python3.9/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/anaconda3/envs/fipa/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
# ...
